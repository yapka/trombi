# %% [markdown]
# <a href="https://colab.research.google.com/github/yapka/trombi/blob/master/data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

aisles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data exploration/aisles.csv')
departments= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data exploration/departments.csv')

aisles
departments
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing
